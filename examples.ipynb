# %%
import nfl_data_py as nfl

# %%
#Used to test/sample different pandas df functions. Weekly data from the NFL 2021 season
example = nfl.import_weekly_data(range(2021,2022))
example
# Out:
# Downcasting floats.
#        player_id player_name player_display_name position position_group  \
# 0     00-0019596     T.Brady           Tom Brady       QB             QB
# 1     00-0019596     T.Brady           Tom Brady       QB             QB
# 2     00-0019596     T.Brady           Tom Brady       QB             QB
# 3     00-0019596     T.Brady           Tom Brady       QB             QB
# 4     00-0019596     T.Brady           Tom Brady       QB             QB
# ...          ...         ...                 ...      ...            ...
# 5693  00-0037013    Z.Wilson         Zach Wilson       QB             QB
# 5694  00-0037013    Z.Wilson         Zach Wilson       QB             QB
# 5695  00-0037013    Z.Wilson         Zach Wilson       QB             QB
# 5696  00-0037013    Z.Wilson         Zach Wilson       QB             QB
# 5697  00-0037013    Z.Wilson         Zach Wilson       QB             QB
#
# ...

# %%
#All values that can be used to compare weekly player information
nfl.see_weekly_cols()
# Out:
# Index(['player_id', 'player_name', 'player_display_name', 'position',
#        'position_group', 'headshot_url', 'recent_team', 'season', 'week',
#        'season_type', 'completions', 'attempts', 'passing_yards',
#        'passing_tds', 'interceptions', 'sacks', 'sack_yards', 'sack_fumbles',
#        'sack_fumbles_lost', 'passing_air_yards', 'passing_yards_after_catch',
#        'passing_first_downs', 'passing_epa', 'passing_2pt_conversions', 'pacr',
#        'dakota', 'carries', 'rushing_yards', 'rushing_tds', 'rushing_fumbles',
#        'rushing_fumbles_lost', 'rushing_first_downs', 'rushing_epa',
#        'rushing_2pt_conversions', 'receptions', 'targets', 'receiving_yards',
#        'receiving_tds', 'receiving_fumbles', 'receiving_fumbles_lost',
#        'receiving_air_yards', 'receiving_yards_after_catch',
#        'receiving_first_downs', 'receiving_epa', 'receiving_2pt_conversions',
#        'racr', 'target_share', 'air_yards_share', 'wopr', 'special_teams_tds',
# ...

# %%
#Simple functions to see first x values of a df
example.head(2)
# Out:
#     player_id player_name player_display_name position position_group  \
# 0  00-0019596     T.Brady           Tom Brady       QB             QB
# 1  00-0019596     T.Brady           Tom Brady       QB             QB
#
#                                         headshot_url recent_team  season  \
# 0  https://static.www.nfl.com/image/private/f_aut...          TB    2021
# 1  https://static.www.nfl.com/image/private/f_aut...          TB    2021
#
#    week season_type  ...  receiving_first_downs  receiving_epa  \
# 0     1         REG  ...                    0.0            NaN
# 1     2         REG  ...                    0.0            NaN
#
#    receiving_2pt_conversions  racr  target_share  air_yards_share  wopr  \
# 0                          0   NaN           NaN              NaN   NaN
# 1                          0   NaN           NaN              NaN   NaN
#
#    special_teams_tds  fantasy_points  fantasy_points_ppr
# 0                0.0       27.160000           27.160000
# ...

# %%
#Simple functions to see last x values of a df
example.tail(2)
# Out:
#        player_id player_name player_display_name position position_group  \
# 5696  00-0037013    Z.Wilson         Zach Wilson       QB             QB
# 5697  00-0037013    Z.Wilson         Zach Wilson       QB             QB
#
#                                            headshot_url recent_team  season  \
# 5696  https://static.www.nfl.com/image/private/f_aut...         NYJ    2021
# 5697  https://static.www.nfl.com/image/private/f_aut...         NYJ    2021
#
#       week season_type  ...  receiving_first_downs  receiving_epa  \
# 5696    17         REG  ...                    0.0            NaN
# 5697    18         REG  ...                    0.0            NaN
#
#       receiving_2pt_conversions  racr  target_share  air_yards_share  wopr  \
# 5696                          0   NaN           NaN              NaN   NaN
# 5697                          0   NaN           NaN              NaN   NaN
#
#       special_teams_tds  fantasy_points  fantasy_points_ppr
# ...

# %%
#Shows number of entries
example.index
# Out:
# RangeIndex(start=0, stop=5698, step=1)

# %%
#Shows how entries can be compared
example.columns
# Out:
# Index(['player_id', 'player_name', 'player_display_name', 'position',
#        'position_group', 'headshot_url', 'recent_team', 'season', 'week',
#        'season_type', 'completions', 'attempts', 'passing_yards',
#        'passing_tds', 'interceptions', 'sacks', 'sack_yards', 'sack_fumbles',
#        'sack_fumbles_lost', 'passing_air_yards', 'passing_yards_after_catch',
#        'passing_first_downs', 'passing_epa', 'passing_2pt_conversions', 'pacr',
#        'dakota', 'carries', 'rushing_yards', 'rushing_tds', 'rushing_fumbles',
#        'rushing_fumbles_lost', 'rushing_first_downs', 'rushing_epa',
#        'rushing_2pt_conversions', 'receptions', 'targets', 'receiving_yards',
#        'receiving_tds', 'receiving_fumbles', 'receiving_fumbles_lost',
#        'receiving_air_yards', 'receiving_yards_after_catch',
#        'receiving_first_downs', 'receiving_epa', 'receiving_2pt_conversions',
#        'racr', 'target_share', 'air_yards_share', 'wopr', 'special_teams_tds',
# ...

# %%
#Simple build in "summary" function
example.describe
# Out:
# <bound method NDFrame.describe of        player_id player_name player_display_name position position_group  \
# 0     00-0019596     T.Brady           Tom Brady       QB             QB
# 1     00-0019596     T.Brady           Tom Brady       QB             QB
# 2     00-0019596     T.Brady           Tom Brady       QB             QB
# 3     00-0019596     T.Brady           Tom Brady       QB             QB
# 4     00-0019596     T.Brady           Tom Brady       QB             QB
# ...          ...         ...                 ...      ...            ...
# 5693  00-0037013    Z.Wilson         Zach Wilson       QB             QB
# 5694  00-0037013    Z.Wilson         Zach Wilson       QB             QB
# 5695  00-0037013    Z.Wilson         Zach Wilson       QB             QB
# 5696  00-0037013    Z.Wilson         Zach Wilson       QB             QB
# 5697  00-0037013    Z.Wilson         Zach Wilson       QB             QB
#
# ...

# %%
#Transpose data
example.T
# Out:
#                                                                           0     \
# player_id                                                           00-0019596
# player_name                                                            T.Brady
# player_display_name                                                  Tom Brady
# position                                                                    QB
# position_group                                                              QB
# headshot_url                 https://static.www.nfl.com/image/private/f_aut...
# recent_team                                                                 TB
# season                                                                    2021
# week                                                                         1
# season_type                                                                REG
# completions                                                                 32
# ...

# %%
#VERY HELPFUL, primarily for visualization. Sorts all data on one value
example.sort_values(by="fantasy_points",ascending=False)
# Out:
#        player_id player_name player_display_name position position_group  \
# 4398  00-0036223    J.Taylor     Jonathan Taylor       RB             RB
# 5397  00-0036900     J.Chase       Ja'Marr Chase       WR             WR
# 4353  00-0036196     G.Davis          Gabe Davis       WR             WR
# 4761  00-0036355   J.Herbert      Justin Herbert       QB             QB
# 3201  00-0034796   L.Jackson       Lamar Jackson       QB             QB
# ...          ...         ...                 ...      ...            ...
# 3410  00-0034899   J.Wolford        John Wolford       QB             QB
# 5194  00-0036652    R.McMath        Racey McMath       WR             WR
# 2487  00-0033895   G.Everett      Gerald Everett       TE             TE
# 5371  00-0036898     D.Mills         Davis Mills       QB             QB
# 685   00-0030520   M.Glennon        Mike Glennon       QB             QB
#
#                                            headshot_url recent_team  season  \
# ...

# %%
#You can also slice the dataframe
example[0:3]
# Out:
#     player_id player_name player_display_name position position_group  \
# 0  00-0019596     T.Brady           Tom Brady       QB             QB
# 1  00-0019596     T.Brady           Tom Brady       QB             QB
# 2  00-0019596     T.Brady           Tom Brady       QB             QB
#
#                                         headshot_url recent_team  season  \
# 0  https://static.www.nfl.com/image/private/f_aut...          TB    2021
# 1  https://static.www.nfl.com/image/private/f_aut...          TB    2021
# 2  https://static.www.nfl.com/image/private/f_aut...          TB    2021
#
#    week season_type  ...  receiving_first_downs  receiving_epa  \
# 0     1         REG  ...                    0.0            NaN
# 1     2         REG  ...                    0.0            NaN
# 2     3         REG  ...                    0.0            NaN
#
#    receiving_2pt_conversions  racr  target_share  air_yards_share  wopr  \
# ...

# %%
#Slicing to analyze different values works best using the loc functions
example.loc[:, ["player_name","position","week"]]
# Out:
#      player_name position  week
# 0        T.Brady       QB     1
# 1        T.Brady       QB     2
# 2        T.Brady       QB     3
# 3        T.Brady       QB     4
# 4        T.Brady       QB     5
# ...          ...      ...   ...
# 5693    Z.Wilson       QB    14
# 5694    Z.Wilson       QB    15
# 5695    Z.Wilson       QB    16
# 5696    Z.Wilson       QB    17
# 5697    Z.Wilson       QB    18
#
# [5698 rows x 3 columns]

# %%
#Slicing can work both ways
example.loc[0:2, ]
# Out:
#     player_id player_name player_display_name position position_group  \
# 0  00-0019596     T.Brady           Tom Brady       QB             QB
# 1  00-0019596     T.Brady           Tom Brady       QB             QB
# 2  00-0019596     T.Brady           Tom Brady       QB             QB
#
#                                         headshot_url recent_team  season  \
# 0  https://static.www.nfl.com/image/private/f_aut...          TB    2021
# 1  https://static.www.nfl.com/image/private/f_aut...          TB    2021
# 2  https://static.www.nfl.com/image/private/f_aut...          TB    2021
#
#    week season_type  ...  receiving_first_downs  receiving_epa  \
# 0     1         REG  ...                    0.0            NaN
# 1     2         REG  ...                    0.0            NaN
# 2     3         REG  ...                    0.0            NaN
#
#    receiving_2pt_conversions  racr  target_share  air_yards_share  wopr  \
# ...

# %%
#Slicing can even work on both dimensions at once
example.loc[0:2, ["player_name","position","week"]]
# Out:
#   player_name position  week
# 0     T.Brady       QB     1
# 1     T.Brady       QB     2
# 2     T.Brady       QB     3

# %%
#Better way of slicing if you want to use positional slice indices
example.iloc[0:2,0:6]
# Out:
#     player_id player_name player_display_name position position_group  \
# 0  00-0019596     T.Brady           Tom Brady       QB             QB
# 1  00-0019596     T.Brady           Tom Brady       QB             QB
#
#                                         headshot_url
# 0  https://static.www.nfl.com/image/private/f_aut...
# 1  https://static.www.nfl.com/image/private/f_aut...

# %%
#Pull out one value at one index
example_link = example.at[0,"headshot_url"]
example_link
# Out:
# 'https://static.www.nfl.com/image/private/f_auto,q_auto/league/n7fj5fjblf6pdgjdtphr'

# %%
#Example of using an outside library that accesses data from dataframe
from PIL import Image
import requests
im = Image.open(requests.get(example_link, stream=True).raw)
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=1400x1000>

# %%
#Use isin to help filter values you want
example[example["position"].isin(["WR","RB"])]
# Out:
#        player_id player_name player_display_name position position_group  \
# 70    00-0025394  A.Peterson     Adrian Peterson       RB             RB
# 71    00-0025394  A.Peterson     Adrian Peterson       RB             RB
# 72    00-0025394  A.Peterson     Adrian Peterson       RB             RB
# 73    00-0025394  A.Peterson     Adrian Peterson       RB             RB
# 74    00-0026035  D.Amendola      Danny Amendola       WR             WR
# ...          ...         ...                 ...      ...            ...
# 5651  00-0036999  A.Schwartz    Anthony Schwartz       WR             WR
# 5652  00-0036999  A.Schwartz    Anthony Schwartz       WR             WR
# 5653  00-0036999  A.Schwartz    Anthony Schwartz       WR             WR
# 5654  00-0036999  A.Schwartz    Anthony Schwartz       WR             WR
# 5655  00-0036999  A.Schwartz    Anthony Schwartz       WR             WR
#
#                                            headshot_url recent_team  season  \
# ...

# %%
#See all unique values of a column
example["position"].unique()
# Out:
# array(['QB', 'P', 'TE', 'RB', 'WR', 'T', 'LB', 'FS', 'FB', 'K', 'CB',
#        'SS', 'OLB', 'G', 'ILB', 'DT', 'C', 'DE'], dtype=object)

# %%
example["position_group"].unique()
# Out:
# array(['QB', 'SPEC', 'TE', 'RB', 'WR', 'OL', 'LB', 'DB', 'DL'],
#       dtype=object)
